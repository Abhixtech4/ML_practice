# %% [markdown]
# ### Feature Scaling
#
# Feature scaling makes all numerical features comparable in range.
#
# **Standardization (Z-score):**
# Mean = 0, Std = 1
# Use when data has outliers or is normally distributed.
# Needed for: Linear Regression, Logistic Regression, SVM, KNN, PCA.
#
# **Min-Max Scaling:**
# Scales values between 0 and 1
# Use when you need fixed range values.
# Good for: Neural Networks, KNN, Deep Learning.
#
# **Not needed for:**
# Decision Trees, Random Forest, XGBoost (tree-based models)
#
# > Scaling is important for distance-based and gradient-based models, not for tree models.

# %% [markdown]
# ## 1. Standard Scaler
#
# Scales data so that mean = 0 and standard deviation = 1.
#
# **Dataset used:**
# Wine Quality Dataset
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009?select=winequality-red.csv
#
# **Why use here:**
# Features like alcohol, pH, and acidity are in different ranges. StandardScaler makes them comparable so distance-based models work properly.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("winequality-red.csv")
features = df.drop("quality", axis=1)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(features)

df_scaled = pd.DataFrame(scaled_data, columns=features.columns)
print(df_scaled.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol
# 0 -0.960246
# 1 -0.584777
# 2 -0.584777
# ...

# %% [markdown]
# ## 2. Min-Max Scaler
#
# Scales data between 0 and 1.
#
# **Dataset used:**
# Wine Quality Dataset
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009
#
# **Why use here:**
# Features have different ranges, so Min-Max scaling brings all values to a fixed range and improves model performance (especially for KNN and neural networks).

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("winequality-red.csv")
features = df.drop("quality", axis=1)

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(features)

df_scaled = pd.DataFrame(scaled_data, columns=features.columns)
print(df_scaled.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788          0.397260         0.00        0.068493   0.106845
# 1       0.283186          0.520548         0.00        0.116438   0.143573
# 2       0.283186          0.438356         0.04        0.095890   0.133556
# 3       0.584071          0.109589         0.56        0.068493   0.105175
# 4       0.247788          0.397260         0.00        0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.140845              0.098940  0.567548  0.606299   0.137725
# 1             0.338028              0.215548  0.494126  0.362205   0.209581
# 2             0.197183              0.169611  0.508811  0.409449   0.191617
# 3             0.225352              0.190813  0.582232  0.330709   0.149701
# 4             0.140845              0.098940  0.567548  0.606299   0.137725
#
#     alcohol
# 0  0.153846
# 1  0.215385
# 2  0.215385
# ...
